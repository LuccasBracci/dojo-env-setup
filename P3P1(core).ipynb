# %%
import pandas as pd
import pymysql
import numpy as np

# %%
basics_url= "https://datasets.imdbws.com/title.basics.tsv.gz"
ratings_url="https://datasets.imdbws.com/title.ratings.tsv.gz"
akas_url="https://datasets.imdbws.com/title.akas.tsv.gz"

# %%
basics = pd.read_csv(basics_url, sep='\t', low_memory=False,)
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False,)
akas = pd.read_csv(akas_url, sep='\t', low_memory=False)

# %%
basics
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9926874  tt9916848  tvEpisode              Episode #3.17
# 9926875  tt9916850  tvEpisode              Episode #3.19
# 9926876  tt9916852  tvEpisode              Episode #3.20
# 9926877  tt9916856      short                   The Wind
# 9926878  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894      \N              1
# 1           Le clown et ses chiens       0      1892      \N              5
# ...

# %%
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1979
# 1        tt0000002            5.8       265
# 2        tt0000003            6.5      1832
# 3        tt0000004            5.6       179
# 4        tt0000005            6.2      2621
# ...            ...            ...       ...
# 1318731  tt9916730            8.3        10
# 1318732  tt9916766            7.0        21
# 1318733  tt9916778            7.2        36
# 1318734  tt9916840            7.5         7
# 1318735  tt9916880            7.0         7
#
# [1318736 rows x 3 columns]

# %%
akas
# Out:
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA       \N
# 1         tt0000001         2                 Carmencita     DE       \N
# 2         tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3         tt0000001         4                 Καρμενσίτα     GR       \N
# 4         tt0000001         5                 Карменсита     RU       \N
# ...             ...       ...                        ...    ...      ...
# 36208232  tt9916852         5             Episódio #3.20     PT       pt
# 36208233  tt9916852         6             Episodio #3.20     IT       it
# 36208234  tt9916852         7               एपिसोड #3.20     IN       hi
# 36208235  tt9916856         1                   The Wind     DE       \N
# 36208236  tt9916856         2                   The Wind     \N       \N
#
#                 types     attributes isOriginalTitle
# ...

# %%
basics.replace({'\\N':np.nan}, inplace= True)
akas.replace({'\\N':np.nan}, inplace= True)
ratings.replace({'\\N':np.nan}, inplace= True)

# %%
basics = basics.dropna(subset=['runtimeMinutes','genres','startYear'])
basics.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle            1
# originalTitle           1
# isAdult                 0
# startYear               0
# endYear           2643953
# runtimeMinutes          0
# genres                  0
# dtype: int64

# %% [markdown]
# # aka's cleaning

# %%
akas = akas[(akas['region'] == 'US')]

# %%
akas
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 36207763  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 36207833  tt9916620         1                          The Copeland Case
# 36207922  tt9916702         1              Loving London: The Playground
# 36207965  tt9916756         1                   Pretty Pretty Black Girl
# 36207981  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# ...

# %% [markdown]
# "akas" Cleaning

# %%
akas
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 36207763  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 36207833  tt9916620         1                          The Copeland Case
# 36207922  tt9916702         1              Loving London: The Playground
# 36207965  tt9916756         1                   Pretty Pretty Black Girl
# 36207981  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# ...

# %%
akas.replace({'\\N':np.nan}, inplace= True)
# Out:
# C:\Users\Peach\AppData\Local\Temp\ipykernel_52404\3574914546.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   akas.replace({'\\N':np.nan}, inplace= True)

# %%
akas = akas.loc[akas['region'] == 'US']

# %%
akas
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 36207763  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 36207833  tt9916620         1                          The Copeland Case
# 36207922  tt9916702         1              Loving London: The Playground
# 36207965  tt9916756         1                   Pretty Pretty Black Girl
# 36207981  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# ...

# %% [markdown]
# # "Basics" Cleaning

# %%
basics.replace({'\\N':np.nan}, inplace= True)
# Out:
# C:\Users\Peach\AppData\Local\Temp\ipykernel_52404\1844628234.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basics.replace({'\\N':np.nan}, inplace= True)

# %%
basics['runtimeMinutes'].isna().sum()
# Out:
# 0

# %%
basics.dropna(subset=['runtimeMinutes','genres','startYear'], inplace=True)
# Out:
# C:\Users\Peach\AppData\Local\Temp\ipykernel_52404\505536092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basics.dropna(subset=['runtimeMinutes','genres','startYear'], inplace=True)

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2694484 entries, 0 to 9926878
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 205.6+ MB

# %%
basics['startYear']= basics['startYear'].astype(float)
# Out:
# C:\Users\Peach\AppData\Local\Temp\ipykernel_52404\2132963645.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basics['startYear']= basics['startYear'].astype(float)

# %%
basics = basics[(basics['startYear']>=2000)&(basics['startYear']<2022)]

# %%
basics = basics.loc[basics['titleType'] == 'movie']

# %%
basics
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 42384    tt0043139     movie
# 61115    tt0062336     movie
# 67668    tt0069049     movie
# 86800    tt0088751     movie
# ...            ...       ...
# 9926017  tt9914942     movie
# 9926412  tt9915872     movie
# 9926552  tt9916170     movie
# 9926561  tt9916190     movie
# 9926645  tt9916362     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 42384                          Life of a Beijing Policeman
# 61115    The Tango of the Widower and Its Distorting Mi...
# 67668                           The Other Side of the Wind
# 86800                                    The Naked Monster
# ...                                                    ...
# 9926017                             Life Without Sara Amat
# 9926412                               The Last White Witch
# 9926552                                      The Rehearsal
# ...

# %%
basics_is_doc = basics['genres'].str.contains('Documentary', case=False)

# %%
basics = basics[~basics_is_doc]

# %%
basics = basics[basics['tconst'].isin(akas['titleId'])]

# %%
ratings = ratings[ratings['tconst'].isin(akas['titleId'])]

# %%
basics['titleType'].unique()
# Out:
# array(['movie'], dtype=object)

# %%
basics
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 42384    tt0043139     movie
# 61115    tt0062336     movie
# 67668    tt0069049     movie
# 86800    tt0088751     movie
# ...            ...       ...
# 9926017  tt9914942     movie
# 9926412  tt9915872     movie
# 9926552  tt9916170     movie
# 9926561  tt9916190     movie
# 9926645  tt9916362     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 42384                          Life of a Beijing Policeman
# 61115    The Tango of the Widower and Its Distorting Mi...
# 67668                           The Other Side of the Wind
# 86800                                    The Naked Monster
# ...                                                    ...
# 9926017                             Life Without Sara Amat
# 9926412                               The Last White Witch
# 9926552                                      The Rehearsal
# ...

# %%
keepers =basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 34803      True
# 42384      True
# 61115      True
# 67668      True
# 86800      True
#            ...
# 9926017    True
# 9926412    True
# 9926552    True
# 9926561    True
# 9926645    True
# Name: tconst, Length: 81762, dtype: bool

# %%
basics = basics[keepers]
basics
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 42384    tt0043139     movie
# 61115    tt0062336     movie
# 67668    tt0069049     movie
# 86800    tt0088751     movie
# ...            ...       ...
# 9926017  tt9914942     movie
# 9926412  tt9915872     movie
# 9926552  tt9916170     movie
# 9926561  tt9916190     movie
# 9926645  tt9916362     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 42384                          Life of a Beijing Policeman
# 61115    The Tango of the Widower and Its Distorting Mi...
# 67668                           The Other Side of the Wind
# 86800                                    The Naked Monster
# ...                                                    ...
# 9926017                             Life Without Sara Amat
# 9926412                               The Last White Witch
# 9926552                                      The Rehearsal
# ...

# %% [markdown]
# # "Ratings" Cleaning

# %%
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1979
# 1        tt0000002            5.8       265
# 4        tt0000005            6.2      2621
# 5        tt0000006            5.1       182
# 6        tt0000007            5.4       821
# ...            ...            ...       ...
# 1318697  tt9916200            8.1       229
# 1318698  tt9916204            8.2       263
# 1318705  tt9916348            8.3        18
# 1318706  tt9916362            6.4      5374
# 1318711  tt9916428            3.8        14
#
# [501008 rows x 3 columns]

# %%
ratings.replace({'\\N':np.nan}, inplace= True)

# %% [markdown]
# # Evaluation

# %%
# Print summary information for each dataframe
print("Summary for 'basics' dataframe:")
print(basics.info())
# Out:
# Summary for 'basics' dataframe:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81762 entries, 34803 to 9926645
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          81762 non-null  object
#  1   titleType       81762 non-null  object
#  2   primaryTitle    81762 non-null  object
#  3   originalTitle   81762 non-null  object
#  4   isAdult         81762 non-null  object
#  5   startYear       81762 non-null  float64
#  6   endYear         0 non-null      object
#  7   runtimeMinutes  81762 non-null  object
#  8   genres          81762 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 6.2+ MB
# None

# %%
print("Summary for 'ratings' dataframe:")
print(ratings.info())
# Out:
# Summary for 'ratings' dataframe:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 501008 entries, 0 to 1318711
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         501008 non-null  object
#  1   averageRating  501008 non-null  float64
#  2   numVotes       501008 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 15.3+ MB
# None

# %%
print("Summary for 'akas' dataframe:")
print(akas.info())
# Out:
# Summary for 'akas' dataframe:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1444607 entries, 5 to 36207981
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   titleId          1444607 non-null  object
#  1   ordering         1444607 non-null  int64
#  2   title            1444607 non-null  object
#  3   region           1444607 non-null  object
#  4   language         3951 non-null     object
#  5   types            980063 non-null   object
#  6   attributes       46754 non-null    object
#  7   isOriginalTitle  1443265 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 99.2+ MB
# None

# %%
basics.to_csv('C:/Users/Peach/Documents/Dojo-env/dojo-env-setup/Proj3P1/IMDB_data/Data/basics.csv.gz', compression='gzip')

ratings.to_csv('C:/Users/Peach/Documents/Dojo-env/dojo-env-setup/Proj3P1/IMDB_data/Data/ratings.csv.gz',compression='gzip')

akas.to_csv('C:/Users/Peach/Documents/Dojo-env/dojo-env-setup/Proj3P1/IMDB_data/Data/akas.csv.gz',compression='gzip')
